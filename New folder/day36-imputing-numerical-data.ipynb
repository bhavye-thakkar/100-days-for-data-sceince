# %%
import pandas as pd
from sklearn.model_selection import train_test_split
import numpy as np
import matplotlib.pyplot as plt

from sklearn.impute import SimpleImputer
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.metrics import accuracy_score
from sklearn.linear_model import LogisticRegression

# %%
df = pd.read_csv('titanic_toy.csv')
df.sample(5)
# Out:
#       Age      Fare  Family  Survived
# 359   NaN    7.8792       0         1
# 551  27.0   26.0000       0         0
# 527   NaN  221.7792       0         0
# 649  23.0       NaN       0         1
# 9    14.0   30.0708       1         1

# %%
df.describe()
# Out:
#               Age        Fare      Family    Survived
# count  714.000000  846.000000  891.000000  891.000000
# mean    29.699118   32.279338    0.904602    0.383838
# std     14.526497   50.305796    1.613459    0.486592
# min      0.420000    0.000000    0.000000    0.000000
# 25%     20.125000    7.895800    0.000000    0.000000
# 50%     28.000000   14.454200    0.000000    0.000000
# 75%     38.000000   31.206250    1.000000    1.000000
# max     80.000000  512.329200   10.000000    1.000000

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Age       714 non-null    float64
#  1   Fare      846 non-null    float64
#  2   Family    891 non-null    int64
#  3   Survived  891 non-null    int64
# dtypes: float64(2), int64(2)
# memory usage: 28.0 KB

# %%
df.isnull().mean()
# Out:
# Age         0.198653
# Fare        0.050505
# Family      0.000000
# Survived    0.000000
# dtype: float64

# %%
x = df.drop(columns=['Survived'])
y = df['Survived']

# %%
x_train , x_test , y_train , y_test = train_test_split(x, y, test_size=0.3, random_state=42)

# %%
x_train.shape, x_test.shape
# Out:
# ((623, 3), (268, 3))

# %%
x_train.isnull().mean()
# Out:
# Age       0.199037
# Fare      0.048154
# Family    0.000000
# dtype: float64

# %%
mean_age = x_train['Age'].mean()
median_age =  x_train['Age'].median()

mean_fare = x_train['Fare'].mean()
median_fare = x_train['Fare'].median()

# %%
x_train['Age_mean'] = x_train['Age'].fillna(mean_age)
x_train['Age_median'] = x_train['Age'].fillna(median_age)
x_train['Fare_mean'] = x_train['Fare'].fillna(mean_fare)
x_train['Fare_median'] = x_train['Fare'].fillna(median_fare)

# %%
x_train.sample(5)
# Out:
#       Age      Fare  Family   Age_mean  Age_median  Fare_mean  Fare_median
# 50    7.0   39.6875       5   7.000000         7.0    39.6875      39.6875
# 386   1.0   46.9000       7   1.000000         1.0    46.9000      46.9000
# 557   NaN  227.5250       0  29.256353        28.0   227.5250     227.5250
# 318  31.0  164.8667       2  31.000000        31.0   164.8667     164.8667
# 613   NaN    7.7500       0  29.256353        28.0     7.7500       7.7500

# %%
print('Original Age variable variance: ', x_train['Age'].var())
print('Age Variance after median imputation: ', x_train['Age_median'].var())
print('Age Variance after mean imputation: ', x_train['Age_mean'].var())

print('Original Fare variable variance: ', x_train['Fare'].var())
print('Fare Variance after median imputation: ', x_train['Fare_median'].var())
print('Fare Variance after mean imputation: ', x_train['Fare_mean'].var())
# Out:
# Original Age variable variance:  211.9518806464334
# Age Variance after median imputation:  169.94984651902163
# Age Variance after mean imputation:  169.69780797736954
# Original Fare variable variance:  2666.9296723129737
# Fare Variance after median imputation:  2552.1099348908238
# Fare Variance after mean imputation:  2538.2996238091323

# %%
#this is the red flag
fig = plt.figure()
ax = fig.add_subplot(111)

# original variable distribution
x_train['Age'].plot(kind='kde', ax=ax)

# variable imputed with the median
x_train['Age_median'].plot(kind='kde', ax=ax, color='red')

# variable imputed with the mean
x_train['Age_mean'].plot(kind='kde', ax=ax, color='green')

# add legends
lines, labels = ax.get_legend_handles_labels()
ax.legend(lines, labels, loc='best')

# %%
# this is the green flag
fig = plt.figure()
ax = fig.add_subplot(111)

# original variable distribution
x_train['Fare'].plot(kind='kde', ax=ax)

# variable imputed with the median
x_train['Fare_median'].plot(kind='kde', ax=ax, color='red')

# variable imputed with the mean
x_train['Fare_mean'].plot(kind='kde', ax=ax, color='green')

# add legends
lines, labels = ax.get_legend_handles_labels()
ax.legend(lines, labels, loc='best')

# %%
x_train.cov() #co-variance
# Out:
#                     Age         Fare     Family    Age_mean  Age_median  \
# Age          211.951881    71.822073  -6.932603  211.951881  211.951881
# Fare          71.822073  2666.929672  18.612474   56.998513   59.765747
# Family        -6.932603    18.612474   2.997027   -5.550541   -5.533529
# Age_mean     211.951881    56.998513  -5.550541  169.697808  169.697808
# Age_median   211.951881    59.765747  -5.533529  169.697808  169.949847
# Fare_mean     67.757268  2666.929672  17.714766   54.249388   56.883154
# Fare_median   65.775061  2666.929672  17.767537   52.662348   55.227061
#
#                Fare_mean  Fare_median
# Age            67.757268    65.775061
# Fare         2666.929672  2666.929672
# Family         17.714766    17.767537
# Age_mean       54.249388    52.662348
# Age_median     56.883154    55.227061
# Fare_mean    2538.299624  2538.299624
# Fare_median  2538.299624  2552.109935

# %%
x_train.corr() #co-relation
# Out:
#                   Age      Fare    Family  Age_mean  Age_median  Fare_mean  \
# Age          1.000000  0.088197 -0.310167  1.000000    1.000000   0.085804
# Fare         0.088197  1.000000  0.205140  0.084564    0.088616   1.000000
# Family      -0.310167  0.205140  1.000000 -0.246123   -0.245186   0.203104
# Age_mean     1.000000  0.084564 -0.246123  1.000000    0.999258   0.082658
# Age_median   1.000000  0.088616 -0.245186  0.999258    1.000000   0.086607
# Fare_mean    0.085804  1.000000  0.203104  0.082658    0.086607   1.000000
# Fare_median  0.083017  1.000000  0.203157  0.080023    0.083857   0.997291
#
#              Fare_median
# Age             0.083017
# Fare            1.000000
# Family          0.203157
# Age_mean        0.080023
# Age_median      0.083857
# Fare_mean       0.997291
# Fare_median     1.000000

# %%
# red- flag ncz there are outliers in the data and mean is affected by outliers
x_train[['Age', 'Age_median', 'Age_mean']].boxplot()
# Out:
# <Axes: >

# %%
# this is greem flag ncz there are no outliers in the data and mean is not affected by outliers
x_train[['Fare', 'Fare_mean', 'Fare_median']].boxplot()
# Out:
# <Axes: >

# %% [markdown]
# #### using sklearn

# %%
imputer1 = SimpleImputer(strategy='median')
imputer2 = SimpleImputer(strategy='mean')

# %%
trf = ColumnTransformer([
    ('imputer1', imputer1, ['Age']),
    ('imputer2', imputer2, ['Fare'])
])

# %%
trf.fit(x_train)
# Out:
# ColumnTransformer(transformers=[('imputer1', SimpleImputer(strategy='median'),
#                                  ['Age']),
#                                 ('imputer2', SimpleImputer(), ['Fare'])])

# %%
trf.named_transformers_['imputer1'].statistics_ # median of age
# Out:
# array([28.])

# %%
trf.named_transformers_['imputer2'].statistics_ # mean of fare
# Out:
# array([31.79834806])

# %%
x_train = trf.fit_transform(x_train)
x_test = trf.transform(x_test)

# %%
clf = LogisticRegression()

# %%
clf.fit(x_train, y_train)
# Out:
# LogisticRegression()

# %%
y_pred = clf.predict(x_test)

# %%
accuracy_score(y_test, y_pred)
# Out:
# 0.6492537313432836
