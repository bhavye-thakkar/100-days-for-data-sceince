# %%
import pickle 
import numpy as np

# %%
pipe = pickle.load(open('titanic_pipe.pkl', 'rb'))

# %%
#assume user input
user_input_2 = np.array([2, 'male', 31.0 , 0 , 0 , 10.5, 'S'],dtype=object).reshape(1, 7)

# %%
user_input_2
# Out:
# array([[2, 'male', 31.0, 0, 0, 10.5, 'S']], dtype=object)

# %%
pipe.predict(user_input_2)
# Out:
# C:\Users\bhavy\AppData\Roaming\Python\Python314\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but SimpleImputer was fitted with feature names
#   warnings.warn(
# C:\Users\bhavy\AppData\Roaming\Python\Python314\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but SimpleImputer was fitted with feature names
#   warnings.warn(
# array([0])
