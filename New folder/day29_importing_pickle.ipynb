# %%
import pickle
import numpy as np

# %%
ohe_sex = pickle.load(open('models/ohe_sex.pkl','rb'))
ohe_embarked = pickle.load(open('models/ohe_embarked.pkl','rb'))
clf = pickle.load(open('models/clf.pkl','rb'))

# %%
#assume user input
#pclass gendee  age embarked sibsp parch fare

user_input = np.array([2,'male',31.0,0,7.25,'S'],dtype=object).reshape(1,6)

# %%
user_input
# Out:
# array([[2, 'male', 31.0, 0, 7.25, 'S']], dtype=object)

# %%
user_input_sex =ohe_sex.transform(user_input[:,1].reshape(1,1))
# Out:
# C:\Users\bhavy\AppData\Roaming\Python\Python314\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but OneHotEncoder was fitted with feature names
#   warnings.warn(

# %%
user_input_sex
# Out:
# array([[0., 1.]])

# %%
user_input_embarked = ohe_embarked.transform(user_input[:,-1].reshape(1,1))
# Out:
# C:\Users\bhavy\AppData\Roaming\Python\Python314\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but OneHotEncoder was fitted with feature names
#   warnings.warn(

# %%
user_input_embarked
# Out:
# array([[0., 0., 1., 0.]])

# %%
user_input_age = user_input[:,2].reshape(1,1)

# %%
user_input_age
# Out:
# array([[31.0]], dtype=object)

# %%
user_input_transformed = np.concatenate(
    (
        user_input[:, [0, 3, 4, 5]],   # Pclass, SibSp, Parch, Fare
        user_input_age,
        user_input_sex,
        user_input_embarked
    ),
    axis=1
)

# %%
user_input_transformed.shape
# Out:
# (1, 11)
